# %%
# List ---> [ ]

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# 2

# %%
l[2]
# Out:
# 3

# %%
l[2] = 300

# %%
l
# Out:
# [1, 2, 300, 4, 5]

# %%
c = ['white', 'black', 'orange', 'green', 'red']

# %%
c
# Out:
# ['white', 'black', 'orange', 'green', 'red']

# %%
c[1]
# Out:
# 'black'

# %%
c[-1]
# Out:
# 'red'

# %%
c[1]
# Out:
# 'black'

# %%
c[1] = 'pink'

# %%
c
# Out:
# ['white', 'pink', 'orange', 'green', 'red']

# %%
c[0:3]
# Out:
# ['white', 'pink', 'orange']

# %%
c[1:4]
# Out:
# ['pink', 'orange', 'green']

# %%
c[:]
# Out:
# ['white', 'pink', 'orange', 'green', 'red']

# %%
c[::-1]
# Out:
# ['red', 'green', 'orange', 'pink', 'white']

# %%
n = [1,2,3,[20,30,40],4,5,6]

# %%
n[3]
# Out:
# [20, 30, 40]

# %%
n[3][1]
# Out:
# 30

# %%
l
# Out:
# [1, 2, 300, 4, 5]

# %%
l.append([10,20,30])

# %%
l
# Out:
# [1, 2, 300, 4, 5, [10, 20, 30]]

# %%
l.extend([10,20,30])

# %%
l
# Out:
# [1, 2, 300, 4, 5, [10, 20, 30], 10, 20, 30]

# %%
l.count(5)
# Out:
# 1

# %%
# Tuple

# %%
p = (1,2,3,4)

# %%
p
# Out:
# (1, 2, 3, 4)

# %%
type(p)
# Out:
# tuple

# %%
p[1]
# Out:
# 2

# %%
p[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 p[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuple immutable

# %%
o = (1,1,1,2,2,3,3,4)

# %%
o
# Out:
# (1, 1, 1, 2, 2, 3, 3, 4)

# %%
o.count(1)
# Out:
# 3

# %%
# set

# %%
s = {1,1,1,1,2,3,3,3,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
n = {'om', 'sham', 'ganesh', 'om'}

# %%
n
# Out:
# {'ganesh', 'om', 'sham'}

# %%
# name ---> char single

# %%
set('vaibhav')
# Out:
# {'a', 'b', 'h', 'i', 'v'}

# %%
# dict key and values

# %%
d = {'name':'Vaibhav', 'Mobile': 1332323, 'Roll':3}

# %%
d
# Out:
# {'name': 'Vaibhav', 'Mobile': 1332323, 'Roll': 3}

# %%
i = {'names':['om', 'sham', 'ganesh', 'om'], 'Roll': [1,2,3,4] }

# %%
i
# Out:
# {'names': ['om', 'sham', 'ganesh', 'om'], 'Roll': [1, 2, 3, 4]}

# %%
def greet():
    print('Hello')

# %%
greet()
# Out:
# Hello

# %%
greet()
# Out:
# Hello

# %%
def seqare(a):
    print(a*a)

# %%
seqare(7)
# Out:
# 49

# %%
def even_odd(a):
    """This is even odd funcction.
    You have to pass value a."""
    if a  %  2 == 0:
        print('even', a)
    else:
        print('Odd',a)

# %%
even_odd(9)
# Out:
# Odd 9

# %%
even_odd()

# %%
seqare(7)
# Out:
# 49

# %%
type(seqare(5))
# Out:
# 25
# NoneType

# %%
def new_sq(a):
    return a*a

# %%
new_sq(6)
# Out:
# 36

# %%
type(new_sq(5))
# Out:
# int

# %%
def test1(*args):
    return args

# %%
test1(1,35,24,52,5,23,12)
# Out:
# (1, 35, 24, 52, 5, 23, 12)

# %%
# filter out only int type of data

# %%
def test2(*args):
    l = []
    for i in args:
        if type(i) == int:
            l.append(i)
    return l

# %%
test2('hello', 1.5, 2, True,  100)
# Out:
# [2, 100]

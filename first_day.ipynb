# %%
10 + 54
# Out:
# 64

# %%
10
# Out:
# 10

# %%
type(10)
# Out:
# int

# %%
type()

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
3 ** 2
# Out:
# 9

# %%
10 ** 5
# Out:
# 100000

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
type(12)
# Out:
# int

# %%
type('hello')
# Out:
# str

# %%
type = 10

# %%
type
# Out:
# 10

# %%
type('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 type('hello')
#
# TypeError: 'int' object is not callable
